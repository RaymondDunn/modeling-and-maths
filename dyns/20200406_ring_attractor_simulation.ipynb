# %%
"""
From meeting with SK on 20200407

Start with equations, see vector fields, plot basins of attraction.

Write down differential equations for ring attractor, plot vector field, color basins of attraction. Don't read anything more just ask yourself simplest math for point attractor. 

Fixed point: dxdt and dydt is zero. Write down simplest equation for simplest fixed point attractor. Then go to two points. Then go from there to build. 
"""

# So our goal here is to start with an equation for a fixed point attractor and build slowly from there

# %%
import numpy as np
import matplotlib.pyplot as plt
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
# %matplotlib qt

# Simple function for euler approximation of dyns
#def run_simulation(dt=0.01, num_steps=2000, ics=(0., 1., 1.05)):
def run_simulation(dt=0.01, num_steps=2000, ics=(0., 1.)):
    # Need one more for the initial values
    xs = np.empty(num_steps + 1)
    ys = np.empty(num_steps + 1)
    #zs = np.empty(num_steps + 1)

    # Set initial values
    #xs[0], ys[0], zs[0] = ics
    xs[0], ys[0] = ics

    # Step through "time", calculating the partial derivatives at the current point
    # and using them to estimate the next point
    for i in range(num_steps):

        # calculate next step
        #x_dot, y_dot, z_dot = dyns(xs[i], ys[i], zs[i])
        x_dot, y_dot = f(xs[i], ys[i])
        xs[i + 1] = xs[i] + (x_dot * dt)
        ys[i + 1] = ys[i] + (y_dot * dt)
        #zs[i + 1] = zs[i] + (z_dot * dt)
    
    #return xs, ys, zs
    return xs, ys

def plot_simulation(xs, ys, title_suffix=''):

    # Plot
    #fig = plt.figure()
    #ax = fig.gca(projection='3d')
    ax = plt.subplot(111)
    
    # coloring
    #cs = plt.get_cmap('viridis', len(xs)).colors
    #ax.scatter(xs, ys, zs, lw=0.5, c=cs)
    
    colorline(xs, ys, cmap=plt.get_cmap('jet'))

    #ax.plot(xs, ys, lw=0.5)
    
    ax.set_xlabel("X Axis")
    ax.set_ylabel("Y Axis")
    #ax.set_zlabel("Z Axis")
    ax.set_title("Simulation".format(title_suffix))
    
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.collections as mcoll
import matplotlib.path as mpath

def colorline(
    x, y, z=None, cmap=plt.get_cmap('copper'), norm=plt.Normalize(0.0, 1.0),
        linewidth=3, alpha=1.0):
    """
    http://nbviewer.ipython.org/github/dpsanders/matplotlib-examples/blob/master/colorline.ipynb
    http://matplotlib.org/examples/pylab_examples/multicolored_line.html
    Plot a colored line with coordinates x and y
    Optionally specify colors in the array z
    Optionally specify a colormap, a norm function and a line width
    """

    # Default colors equally spaced on [0,1]:
    if z is None:
        z = np.linspace(0.0, 1.0, len(x))

    # Special case if a single number:
    if not hasattr(z, "__iter__"):  # to check for numerical input -- this is a hack
        z = np.array([z])

    z = np.asarray(z)

    segments = make_segments(x, y)
    lc = mcoll.LineCollection(segments, array=z, cmap=cmap, norm=norm,
                              linewidth=linewidth, alpha=alpha)

    ax = plt.gca()
    ax.add_collection(lc)
    ax.set_xlim(x.min() - 0.1 * x.max(), x.max() + 0.1*x.max())
    ax.set_ylim(ys.min() - 0.1 * y.max(), ys.max() + 0.1 * y.max())

    return lc


def make_segments(x, y):
    """
    Create list of line segments from x and y coordinates, in the correct format
    for LineCollection: an array of the form numlines x (points per line) x 2 (x
    and y) array
    """

    points = np.array([x, y]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    return segments

    
#def dyns(x, y, z, s=10, r=28, b=2.667):
def f(x, y, ops={}):
    
    s=10 
    r=28 
    b=2.667
    x_dot = s*(y - x)
    y_dot = r*x - y
    #z_dot = x*y - b*z
    #x_dot = 
    #y_dot = 
    
    #return x_dot, y_dot, z_dot
    return [x_dot, y_dot]

ops = {}
ics = (0.5, 0.5)
xs, ys, = run_simulation(dt=0.01, num_steps=100)
plot_simulation(xs, ys)

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-127-fb43bfd9b414> in <module>
#       7 tend = 30
#       8 tvec = np.linspace(0, tend, num=int(tend/dt))
# ----> 9 state = odeint(f, ics, tvec)
#
# /opt/anaconda3/envs/jupyter/lib/python3.7/site-packages/scipy/integrate/odepack.py in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     243                              full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     244                              ixpr, mxstep, mxhnil, mxordn, mxords,
# --> 245                              int(bool(tfirst)))
#     246     if output[-1] < 0:
#     247         warning_msg = _msgs[output[-1]] + " Run with full_output = 1 to get quantitative information."
#
# ...

# %%
""" from Miller 2016 Dynamical systems, attractors, and neural circuits

% case 6 produces an oscillator with a triphasic rhythm. Changes in
% initial conditions alter the phase of the oscillation but not the
% pattern, which is an orbit attractor or limit cycle.
Ithresh = [8; 20];
W = [2.2 -1.3; 1.2 -0.1];
rinit1 = [80; 0];
Iapp1 = [0; 0];
Iapp2 = [-10; 0];

"""
# Out:
# ' from Miller 2016 Dynamical systems, attractors, and neural circuits\n\n% case 6 produces an oscillator with a triphasic rhythm. Changes in\n% initial conditions alter the phase of the oscillation but not the\n% pattern, which is an orbit attractor or limit cycle.\nIthresh = [8; 20];\nW = [2.2 -1.3; 1.2 -0.1];\nrinit1 = [80; 0];\nIapp1 = [0; 0];\nIapp2 = [-10; 0];\n\n'

# %%
# 20200415
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.collections as mcoll
import matplotlib.path as mpath

def colorline(
    x, y, z=None, cmap=plt.get_cmap('copper'), norm=plt.Normalize(0.0, 1.0),
        linewidth=3, alpha=1.0):
    """
    http://nbviewer.ipython.org/github/dpsanders/matplotlib-examples/blob/master/colorline.ipynb
    http://matplotlib.org/examples/pylab_examples/multicolored_line.html
    Plot a colored line with coordinates x and y
    Optionally specify colors in the array z
    Optionally specify a colormap, a norm function and a line width
    """

    # Default colors equally spaced on [0,1]:
    if z is None:
        z = np.linspace(0.0, 1.0, len(x))

    # Special case if a single number:
    if not hasattr(z, "__iter__"):  # to check for numerical input -- this is a hack
        z = np.array([z])

    z = np.asarray(z)

    segments = make_segments(x, y)
    lc = mcoll.LineCollection(segments, array=z, cmap=cmap, norm=norm,
                              linewidth=linewidth, alpha=alpha)

    ax = plt.gca()
    ax.add_collection(lc)
    ax.set_xlim(x.min() - 0.1 * x.max(), x.max() + 0.1*x.max())
    ax.set_ylim(ys.min() - 0.1 * y.max(), ys.max() + 0.1 * y.max())

    return lc


def make_segments(x, y):
    """
    Create list of line segments from x and y coordinates, in the correct format
    for LineCollection: an array of the form numlines x (points per line) x 2 (x
    and y) array
    """

    points = np.array([x, y]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    return segments

# %%
import random
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
# %matplotlib qt

def f(state,t):
    
    # unpack the state vector
    x = state[0]
    y = state[1]

    """
    z = state[2]

    # these are our constants
    sigma = 10.0
    rho = 28.0
    beta = 8.0/3.0

    # compute state derivatives
    xd = sigma * (y-x)
    yd = (rho-z)*x - y
    zd = x*y - beta*z

    # return the state derivatives
    return [xd, yd, zd]
    """
    
    xd = -np.log(x) - np.sqrt(y)
    yd = -np.log(y) - np.sqrt(x)
    #xd = 
    #yd = 
    
    
    return [xd, yd]
    

# sets of initial value
# initial conditions
tend = 1
dt = 0.01
tvec = np.linspace(0, tend, num=int(tend/dt))
x0 = list([0.1, 0.3, 0.6, 0.9])
y0 = list([0.1, 0.3, 0.6, 0.9])
total_sps = len(x0) * len(y0)

# plot for each ics
plt.figure(figsize=(10,10))
plot_ndx = 1
for y in y0:
    for x in x0:
        state0 = [x, y]
        state = odeint(f, state0, tvec)
        
        # plot and decorate
        xs = state[:,0]
        ys = state[:,1]
        #plt.figure(figsize=(5,4))
        plt.subplot(4,4,plot_ndx)
        colorline(xs, ys, cmap=plt.get_cmap('jet'))
        plt.title('x0: {}; y0: {}'.format(x, y))
        plot_ndx += 1
    
    
#state0 = [0.5, 0.6]
#tend = 1
#dt = 0.01
#state = odeint(f, state0, tvec)

# %%
# need to pick different ics?
x = np.linspace(0, 1, num=100)
yvals = -np.log(x) + np.log(y)
plt.plot(x, yvals)
# Out:
# /opt/anaconda3/envs/jupyter/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-a02705b2d0e8> in <module>
#       1 # need to pick different ics?
#       2 x = np.linspace(0, 1, num=100)
# ----> 3 yvals = -np.log(x) + np.log(y)
#       4 plt.plot(x, yvals)
#
# NameError: name 'y' is not defined
